# %%
import bw2data as bd
from bw2io import ExcelLCIAImporter, strategies
# Out:
# /Users/mickael/anaconda3/envs/ab/lib/python3.11/site-packages/scikits/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __import__('pkg_resources').declare_namespace(__name__)

# %%
bd.projects.set_current("TCM_tutorial")
bd.databases
# Out:
# Databases dictionary with 10 object(s):
# 	Hydrogen gas fired
# 	PEM
# 	PEM2050
# 	biosphere3
# 	ecoinvent-3.9.1-cutoff
# 	electricity
# 	electricity2050
# 	remind - SSP1-PkBudg500 - 2025
# 	remind - SSP1-PkBudg500 - 2040
# 	remind - SSP1-PkBudg500 - 2050

# %%
categories = {
        (
            (
                "Planetary boundaries",
                "climate change",
                "atmospheric CO2 concentration",
            ),
            "ppm",
            "CO2_concentration.xlsx",
        ),
        (
            (
                "Planetary boundaries",
                "climate change",
                "energy imbalance at top-of-atmosphere",
            ),
            "Wm-2",
            "Radiative_forcing.xlsx",
        ),
        (
            (
                "Planetary boundaries",
                "ozone depletion",
                "stratospheric O3 concentration",
            ),
            "Dobson unit",
            "ozone_depletion.xlsx",
        ),
        (
            (
                "Planetary boundaries",
                "ocean acidification",
                "carbonate ion concentration",
            ),
            "omega aragonite",
            "ocean_acidification.xlsx",
        ),
        (
            ("Planetary boundaries", 
            "biogeochemical flows", 
            "phosphorus"),
            "Tg P",
            "Biochem_P.xlsx",
        ),
        (
            (
                "Planetary boundaries",
                "biogeochemical flows",
                "nitrogen",
            ),
            "Tg N",
            "Biochem_N.xlsx",
        ),
        (
            ("Planetary boundaries", 
            "land-system change", 
            "global"),
            "% forested land",
            "land_change.xlsx",
        ),
        (
            ("Planetary boundaries", 
            "freshwater use", 
            "global"),
            "km3",
            "freshwater.xlsx",
        ),
        (
            (
                "Planetary boundaries",
                "change in biosphere integrity",
                "functional diversity",
            ),
            "% BII loss",
            "biosphere_integrity.xlsx",
        ),
        (
            (
                "Planetary boundaries",
                "atmospheric aerosol loading",
            ),
            "aerosol optical depth",
            "aerosol_loading.xlsx",
        ),
        
    }

# %%
filespath="./characterisation/"
for cat in categories:
    print(f"Adding {cat[0]}")
    method = ExcelLCIAImporter(
                filepath=filespath + cat[-1],
                name=cat[0],
                unit=cat[1],
                description=cat[2],
                filename=cat[-1],
            )
    method.apply_strategies(
                    method.strategies,
                )
    method.drop_unlinked(verbose=False)
    method.write_methods(overwrite=True)
# Out:
# Adding ('Planetary boundaries', 'climate change', 'energy imbalance at top-of-atmosphere')
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: set_biosphere_type
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: link_iterable_by_fields
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applied 8 strategies in 0.15 seconds
# Wrote 1 LCIA methods with 105 characterization factors
# Adding ('Planetary boundaries', 'land-system change', 'global')
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: set_biosphere_type
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: link_iterable_by_fields
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# ...
