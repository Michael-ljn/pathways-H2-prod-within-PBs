# %%
using JuMP,CPLEX,SparseArrays,LinearAlgebra
import Ipopt

# %%
using JuMP,CPLEX,SparseArrays,LinearAlgebra
import Ipopt

model=Model(optimizer_with_attributes(Ipopt.Optimizer))
set_silent(model)

@variable(model,α[1:10])    # allocation factor to solve via optimisation
@variable(model,e[1:10])    # allocation factor to solve via optimisation
ω=8*ones(10)                #weighting factor for planetary boundaries
T=ones(10)                  #impact per planetary boundaries
D=ones(10)                  #demand per planetary boundaries
# @objective(model, Min, e./(α.*ω))


@constraint(model, sum(α) == 1) # The space is limited to 1 (global space)
@constraint(model, α .≥ 0)  # Allocation factor must be non-negative
@constraint(model,  e .== D.*T) # total impact follows the demand
# Out:
# 10-element Vector{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.EqualTo{Float64}}, ScalarShape}}:
#  e[1] = 1
#  e[2] = 1
#  e[3] = 1
#  e[4] = 1
#  e[5] = 1
#  e[6] = 1
#  e[7] = 1
#  e[8] = 1
#  e[9] = 1
#  e[10] = 1
